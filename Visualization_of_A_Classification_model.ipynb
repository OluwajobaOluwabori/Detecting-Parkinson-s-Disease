# %% [markdown]
# <a href="https://colab.research.google.com/github/OluwajobaOluwabori/Detecting-Parkinson-s-Disease/blob/main/Visualization_of_A_Classification_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00471/Data_for_UCI_named.csv')
df.to_csv('Data_for_UCI_named.csv')

# %%
keys = df.keys()
print (keys)
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# tau1     False
# tau2     False
# tau3     False
# tau4     False
# p1       False
# p2       False
# p3       False
# p4       False
# g1       False
# g2       False
# g3       False
# g4       False
# stab     False
# stabf    False
# dtype: bool

# %%
df.corr()
# Out:
#           tau1      tau2      tau3  ...        g3        g4      stab
# tau1  1.000000  0.015586 -0.005970  ... -0.001279  0.005494  0.275761
# tau2  0.015586  1.000000  0.014273  ...  0.016508 -0.011764  0.290975
# tau3 -0.005970  0.014273  1.000000  ...  0.014702 -0.011497  0.280700
# tau4 -0.017265 -0.001965  0.004354  ...  0.003260 -0.000491  0.278576
# p1    0.027183 -0.004769  0.016953  ...  0.001069 -0.015451  0.010278
# p2   -0.015485  0.006573 -0.003134  ...  0.007555  0.019817  0.006255
# p3   -0.015924  0.007673 -0.008780  ... -0.005897 -0.010485 -0.003321
# p4   -0.015807 -0.005963 -0.017531  ... -0.003515  0.017505 -0.020786
# g1    0.010521 -0.001742 -0.011605  ... -0.005836  0.012431  0.282774
# g2    0.015350  0.015383  0.007671  ... -0.012809 -0.014909  0.293601
# g3   -0.001279  0.016508  0.014702  ...  1.000000  0.006900  0.308235
# g4    0.005494 -0.011764 -0.011497  ...  0.006900  1.000000  0.279214
# ...

# %%
#  This function does the actual graphical plotting of the correlation matrix above. 
import matplotlib.pyplot as plt
# %matplotlib inline
def plot_corr(df, size=13):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    mat = ax.matshow(corr, cmap=plt.cm.RdYlGn)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    fig.colorbar(mat)
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
        ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(20)
    fig.savefig('corr_mat.png', bbox_inches='tight')


plot_corr(df_copy)
